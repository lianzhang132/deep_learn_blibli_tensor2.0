# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据集
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
#计算每个批次的大小
batch_size = 100
#计算总共的批次
n_batch = mnist.train.num_examples//batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])
keep_prob = tf.placeholder(tf.float32)
lr = tf.Variable(0.001,dtype=tf.float32)

#创建一个简单地神经网络
#tf.truncated_normal 截断的正态分布  
W1 = tf.Variable(tf.truncated_normal([784,500],stddev=0.1))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)


W2 = tf.Variable(tf.truncated_normal([500,300],stddev=0.1))
b2 = tf.Variable(tf.zeros([300])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([300,300],stddev=0.1))
b3 = tf.Variable(tf.zeros([300])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([300,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)


prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)
#第二个神经元
# W_1 = tf.Variable(tf.zeros([10]))
# b_1 = tf.Variable(tf.zeros([10]))
# prediction = tf.nn.softmax(tf.matmul(prediction_0,W_1)+b_1)

#二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
#对数释然函数 交叉熵
loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))

#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(lr).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
#argmax 返回一维向量中最大的值所在位置
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))


#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(51):
        #每次都改变学习率lr 把0.95**epoch 赋值给lr 学习率 越来越小 
        #因为数据后期还是收敛 不需要那么大的学习率 
        sess.run(tf.assign(lr,0.001*(0.95**epoch)))
        
        for batch in range(n_batch):
            batch_xs,batch_ys= mnist.train.next_batch(batch_size)
            sess.run(train_step,
                     feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})
        test_acc = sess.run(accuracy,
                       feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,
                       feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        learning_rate = sess.run(lr)
        print("ITER"+str(epoch)+",Testing accuracy"+str(test_acc)
              +",learning_rate"+str(learning_rate))
#         print("ITER"+str(epoch)+",training accuracy"+str(train_acc))
# Out:
# WARNING:tensorflow:From <ipython-input-2-accb4d4f2b58>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-2-accb4d4f2b58>:19: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-2-accb4d4f2b58>:46: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# ITER0,Testing accuracy0.1953,learning_rate0.001
# ITER1,Testing accuracy0.2914,learning_rate0.00095
# ITER2,Testing accuracy0.3658,learning_rate0.0009025
# ITER3,Testing accuracy0.4213,learning_rate0.000857375
# ITER4,Testing accuracy0.4715,learning_rate0.00081450626
# ITER5,Testing accuracy0.5386,learning_rate0.0007737809
# ITER6,Testing accuracy0.5887,learning_rate0.0007350919
# ITER7,Testing accuracy0.6193,learning_rate0.0006983373
# ITER8,Testing accuracy0.6486,learning_rate0.0006634204
# ITER9,Testing accuracy0.6831,learning_rate0.0006302494
# ITER10,Testing accuracy0.7078,learning_rate0.0005987369
# ITER11,Testing accuracy0.7235,learning_rate0.0005688001
# ITER12,Testing accuracy0.7342,learning_rate0.0005403601
# ITER13,Testing accuracy0.7423,learning_rate0.0005133421
# ITER14,Testing accuracy0.7475,learning_rate0.000487675
# ITER15,Testing accuracy0.7524,learning_rate0.00046329122
# ITER16,Testing accuracy0.7568,learning_rate0.00044012666
# ITER17,Testing accuracy0.7612,learning_rate0.00041812033
# ITER18,Testing accuracy0.7652,learning_rate0.00039721432
# ITER19,Testing accuracy0.7681,learning_rate0.0003773536
# ITER20,Testing accuracy0.7697,learning_rate0.00035848594
# ITER21,Testing accuracy0.7714,learning_rate0.00034056162
# ITER22,Testing accuracy0.7735,learning_rate0.00032353355
# ITER23,Testing accuracy0.7767,learning_rate0.00030735688
# ITER24,Testing accuracy0.7786,learning_rate0.000291989
# ITER25,Testing accuracy0.7822,learning_rate0.00027738957
# ITER26,Testing accuracy0.7852,learning_rate0.0002635201
# ITER27,Testing accuracy0.7908,learning_rate0.00025034408
# ITER28,Testing accuracy0.798,learning_rate0.00023782688
# ITER29,Testing accuracy0.8054,learning_rate0.00022593554
# ITER30,Testing accuracy0.8118,learning_rate0.00021463877
# ITER31,Testing accuracy0.8187,learning_rate0.00020390682
# ITER32,Testing accuracy0.8239,learning_rate0.00019371149
# ITER33,Testing accuracy0.8275,learning_rate0.0001840259
# ITER34,Testing accuracy0.8309,learning_rate0.00017482461
# ITER35,Testing accuracy0.8348,learning_rate0.00016608338
# ITER36,Testing accuracy0.8374,learning_rate0.00015777921
# ITER37,Testing accuracy0.8407,learning_rate0.00014989026
# ITER38,Testing accuracy0.8426,learning_rate0.00014239574
# ITER39,Testing accuracy0.8439,learning_rate0.00013527596
# ITER40,Testing accuracy0.845,learning_rate0.00012851215
# ITER41,Testing accuracy0.8453,learning_rate0.00012208655
# ITER42,Testing accuracy0.8468,learning_rate0.00011598222
# ITER43,Testing accuracy0.8474,learning_rate0.00011018311
# ITER44,Testing accuracy0.8488,learning_rate0.000104673956
# ITER45,Testing accuracy0.8496,learning_rate9.944026e-05
# ITER46,Testing accuracy0.8502,learning_rate9.446825e-05
# ITER47,Testing accuracy0.8514,learning_rate8.974483e-05
# ITER48,Testing accuracy0.8517,learning_rate8.525759e-05
# ITER49,Testing accuracy0.8525,learning_rate8.099471e-05
# ITER50,Testing accuracy0.8532,learning_rate7.6944976e-05

# %% [markdown]
# proch 1.0 不丢
# ITER30,Testing accuracy0.9723
# ITER30,training accuracy0.9958182
